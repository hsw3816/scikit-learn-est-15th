# %%
pip install kaggle==1.8
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 18.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 10.1/10.1 MB 52.1 MB/s  0:00:00
# ...
#
#    ----------- ----------------------------  4/14 [protobuf]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ---------------------------- ----------- 10/14 [mypy]
#    ------------------------------- -------- 11/14 [kagglesdk]
# ...

# %%
pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imbalanced-learn
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
